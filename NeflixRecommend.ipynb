# %%
import pandas as pd
import random

# %%
best_movie = pd.read_csv("./data/bestmovie.csv")

# %%
best_show = pd.read_csv("./data/bestshow.csv")

# %%
best_movie
# Out:
#      index                                     TITLE  RELEASE_YEAR  SCORE  \
# 0        0  David Attenborough: A Life on Our Planet          2020    9.0
# 1        1                                 Inception          2010    8.8
# 2        2                              Forrest Gump          1994    8.8
# 3        3                                Anbe Sivam          2003    8.7
# 4        4                        Bo Burnham: Inside          2021    8.7
# ..     ...                                       ...           ...    ...
# 382    382                                  The Trip          2021    6.9
# 383    383                                  The Dirt          2019    6.9
# 384    384                                   Top Gun          1986    6.9
# 385    385                               Radhe Shyam          2022    6.9
# 386    386                       Sorry to Bother You          2018    6.9
#
#      NUMBER_OF_VOTES  DURATION   MAIN_GENRE MAIN_PRODUCTION
# ...

# %%
best_show
# Out:
#      index                       TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 0        0                Breaking Bad          2008    9.5          1727694
# 1        1  Avatar: The Last Airbender          2005    9.3           297336
# 2        2                  Our Planet          2019    9.3            41386
# 3        3                Kota Factory          2019    9.3            66985
# 4        4              The Last Dance          2020    9.1           108321
# ..     ...                         ...           ...    ...              ...
# 241    241                 Evil Genius          2018    7.5            27516
# 242    242              13 Reasons Why          2017    7.5           282373
# 243    243                       Lupin          2021    7.5           100575
# 244    244          All of Us Are Dead          2022    7.5            41393
# 245    245     I Am Not Okay with This          2020    7.5            56459
#
# ...

# %%
#CONDITIONS
try:
    watch = int(input("What would you like to watch\nEnter 1 for Shows\nEnter 2 for Movies:"))

    if watch == 1:
        data = best_show
        wh = "Shows"
    elif watch == 2:
        data = best_movie
        wh = "Movies"
    else:
        print("\nINVALID INPUT !!!!!!!!!!!")

    min_rating = float(input("Enter minimum rating : "))
    main_genre = input("Enter Genre : ")
    rel_year = int(input("After which year : "))

except ValueError:
    print("\nINVALID INPUT !!!!!!!!!!!")
# Out:
# What would you like to watch
# Enter 1 for Shows
# Enter 2 for Movies:1
# Enter minimum rating : 7.5
# Enter Genre : crime
# After which year : 2000

# %%
watch_list = []
no_of_movies = 5
for i in range(0,len(data)):
    scr = data.loc[i,"SCORE"]
    genre = data.loc[i,"MAIN_GENRE"]
    year = data.loc[i,"RELEASE_YEAR"]
    if len(watch_list) < no_of_movies:
        if scr >= min_rating and genre == main_genre and year >= rel_year:
            movie = data.loc[i,"TITLE"]
            watch_list.append(movie)
    elif len(watch_list) == 5:
        break

# %%
watch_list
# Out:
# ['Mindhunter', 'Making a Murderer', 'Ozark', 'Babylon Berlin', 'Money Heist']

# %%
num = 1
print(f"Here Are Some Recommended {wh} : ")
for i in watch_list:
    print(f"{num}. {i}")
    num += 1
# Out:
# Here Are Some Recommended Shows :
# 1. Mindhunter
# 2. Making a Murderer
# 3. Ozark
# 4. Babylon Berlin
# 5. Money Heist
